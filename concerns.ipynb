# %% [markdown]
# # 데이터 전처리 과정에서 고민한 것
#
#
# ### 결측치/이상치 확인 및 처리
# - num_words(, 2, 3)의 Z-score나 IQR방법을 사용할 경우 정상적인 데이터가 이상치로 판단됨.
#     -> 특이 데이터 구조임을 확인하고, 데이터 변환이나 도메인 지식 기반 처리 등의 방법 사용 필요
#
# ![alt text](image.png)
#
# ![alt text](image-1.png)
# ![alt text](image-2.png)
# ![alt text](image-3.png)
# ![alt text](image-4.png)
#
#
# ### 주관적인 채점 결과
# - 인종과 TEXT(원문)과의 상관관계
# - 성별과 TEXT(원문)과의 상관관계
# - 채점자가 인간이라는 한계
#     - 후광 효과(Halo effect), 뿔 효과(Horn effect) 등 인간의 인지적 편향과 같은 것들을 그대로 반영해야 하는지,
#     반영한다면 어떻게 나타내야 하는지
#
#
# ### Halo effect
# - 후광 효과
# - 어떤 대상의 한 가지 혹은 일부에 대한 평가가 그의 또 다른 일부 또는 나머지 전부의 평가에 대해 영향을 미치는 인지 편견.
# 주로 긍정적인 일부 측면이 나머지 전반에 걸쳐 긍정적인 평가를 불러오는 경우 쓰인다.
#
# ### Horn effect
# - 사람이나 사물의 단 한 가지 부정적인 특징 때문에 전체적인 평가까지 나쁘게 보게 되는 인지 편견.
# - 후광 효과의 반대 개념
